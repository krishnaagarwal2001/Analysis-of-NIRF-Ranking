# %%
import pandas as pd
Scores=pd.read_csv('Scores_Engineering_2021.csv')
Data=pd.read_csv('GPH_Engineering_2021.csv')
df=pd.merge(Data,Scores,on="Name")
Parameters=['SS','FRU','FSR','FQE','PU','QP','IPR','FPPP','MS','GUE','GPHD','RD','WD','ESCS','PCS','PR']
df=df.drop(Parameters,axis=1)
df.to_csv('GPH.csv',index=False)
df.head(10)
# Out:
#                                                Name  Intake  Admitted  \
# 0             Indian Institute of Technology Madras    4493      4432
# 1              Indian Institute of Technology Delhi    5963      5576
# 2             Indian Institute of Technology Bombay    4872      5070
# 3             Indian Institute of Technology Kanpur    5102      4990
# 4          Indian Institute of Technology Kharagpur    7844      7126
# 5            Indian Institute of Technology Roorkee    5309      5185
# 6           Indian Institute of Technology Guwahati    3879      3651
# 7          Indian Institute of Technology Hyderabad    1272      1245
# 8  National Institute of Technology Tiruchirappalli    4022      3951
# 9        National Institute of Technology Karnataka    4339      3986
#
#    Graduated  Placed  Higher    GPH
# 0       3599    2768     460  28.50
# 1       4181    2506     625  29.53
# 2       3744    2769     430  29.96
# 3       4525    2648    1708  36.55
# ...
